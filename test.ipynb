# %%
import requests
import json

base_url = "http://localhost:8086"


def check_influxdb_health():
    health_url = f"{base_url}/health"
    response = requests.get(health_url)
    if response.status_code == 200:
        return response.json()
    else:
        return None


def get_database_list():
    db_url = f"{base_url}/query?db=_internal&q=SHOW DATABASES"
    response = requests.get(db_url)
    if response.status_code == 200:
        return response.json()
    else:
        return None


def check_database_exists(db_name):
    db_list = get_database_list()
    if db_list and "results" in db_list and len(db_list["results"]) > 0:
        databases = db_list["results"][0]["series"][0]["values"]
        return any(db[0] == db_name for db in databases)
    return False


def inspect_database(db_name):
    if check_database_exists(db_name):
        db_url = f"{base_url}/query?db={db_name}&q=SHOW MEASUREMENTS"
        response = requests.get(db_url)
        if response.status_code == 200:
            return response.json()
        else:
            return None
    else:
        return f"Database '{db_name}' does not exist."

print(f"Health:{check_influxdb_health()}")
print(f"DBList:{get_database_list()}")
print(f"DBExists: {check_database_exists('weatherflow')}")
print(f"DBInspect: {inspect_database('weatherflow')}")
# Out:
# Health:{'checks': [], 'message': 'ready for queries and writes', 'name': 'influxdb', 'status': 'pass', 'version': '1.8.10'}
# DBList:{'results': [{'statement_id': 0, 'series': [{'name': 'databases', 'columns': ['name'], 'values': [['weatherflow'], ['_internal']]}]}]}
# DBExists: True
# DBInspect: {'results': [{'statement_id': 0, 'series': [{'name': 'measurements', 'columns': ['name'], 'values': [['weatherflow_forecast_current'], ['weatherflow_forecast_daily'], ['weatherflow_forecast_hourly'], ['weatherflow_obs'], ['weatherflow_rapid_wind'], ['weatherflow_stats'], ['weatherflow_system_metrics']]}]}]}

# %%
def inspect_series(db_name, series_name):
    if check_database_exists(db_name):
        series_url = f'{base_url}/query?db={db_name}&q=SHOW SERIES FROM "{series_name}"'
        response = requests.get(series_url)
        if response.status_code == 200:
            return response.json()
        else:
            return None
    else:
        return f"Database '{db_name}' does not exist."


series = [
            ["weatherflow_evt_strike"],
            # ["weatherflow_forecast_current"],
            # ["weatherflow_forecast_daily"],
            # ["weatherflow_forecast_hourly"],
            ["weatherflow_obs"],
            ["weatherflow_rapid_wind"],
            ["weatherflow_stats"],
            ["weatherflow_system_metrics"],
        ]

for s in series:
    print(f"SeriesInspect: {inspect_series('weatherflow', s[0])}")
# Out:
# SeriesInspect: {'results': [{'statement_id': 0, 'series': [{'columns': ['key'], 'values': [['weatherflow_evt_strike,collector_type=collector_websocket,device_id=407976,device_name=ST-00173404,device_type=ST,serial_number=ST-00173404,station_elevation=22.802942276000977,station_latitude=28.13533,station_longitude=-82.48492,station_name=Crystal\\ Lake\\ Rd,station_time_zone=America/New_York'], ['weatherflow_evt_strike,collector_type=primary,device_id=407976,device_name=ST-00173404,device_type=ST,serial_number=ST-00173404,station_elevation=22.802942276000977,station_latitude=28.13533,station_longitude=-82.48492,station_name=Crystal\\ Lake\\ Rd,station_time_zone=America/New_York']]}]}]}
# SeriesInspect: {'results': [{'statement_id': 0, 'series': [{'columns': ['key'], 'values': [['weatherflow_obs,collector_type=collector_rest,device_id=407976,device_name=ST-00173404,device_type=ST,serial_number=ST-00173404,station_elevation=22.802942276000977,station_id=171878,station_latitude=28.13533,station_longitude=-82.48492,station_name=Crystal\\ Lake\\ Rd,station_time_zone=America/New_York'], ['weatherflow_obs,collector_type=collector_websocket,device_id=407976,device_name=ST-00173404,device_type=ST,serial_number=ST-00173404,source=mqtt,station_elevation=22.802942276000977,station_latitude=28.13533,station_longitude=-82.48492,station_name=Crystal\\ Lake\\ Rd,station_time_zone=America/New_York,type=obs_st'], ['weatherflow_obs,collector_type=primary,device_id=407976,device_name=ST-00173404,device_type=ST,serial_number=ST-00173404,source=mqtt,station_elevation=22.802942276000977,station_latitude=28.13533,station_longitude=-82.48492,station_name=Crystal\\ Lake\\ Rd,station_time_zone=America/New_York,type=obs_st']]}]}]}
# SeriesInspect: {'results': [{'statement_id': 0, 'series': [{'columns': ['key'], 'values': [['weatherflow_rapid_wind,collector_type=collector_websocket,device_id=407976,device_name=ST-00173404,device_type=ST,serial_number=ST-00173404,station_elevation=22.802942276000977,station_latitude=28.13533,station_longitude=-82.48492,station_name=Crystal\\ Lake\\ Rd,station_time_zone=America/New_York'], ['weatherflow_rapid_wind,collector_type=primary,device_id=407976,device_name=ST-00173404,device_type=ST,serial_number=ST-00173404,station_elevation=22.802942276000977,station_latitude=28.13533,station_longitude=-82.48492,station_name=Crystal\\ Lake\\ Rd,station_time_zone=America/New_York']]}]}]}
# SeriesInspect: {'results': [{'statement_id': 0, 'series': [{'columns': ['key'], 'values': [['weatherflow_stats,collector_type=collector_stats,station_elevation=22.802942276000977,station_id=171878,station_latitude=28.13533,station_longitude=-82.48492,station_name=Crystal\\ Lake\\ Rd,station_time_zone=America/New_York,time_period=Daily'], ['weatherflow_stats,collector_type=collector_stats,station_elevation=22.802942276000977,station_id=171878,station_latitude=28.13533,station_longitude=-82.48492,station_name=Crystal\\ Lake\\ Rd,station_time_zone=America/New_York,time_period=Monthly'], ['weatherflow_stats,collector_type=collector_stats,station_elevation=22.802942276000977,station_id=171878,station_latitude=28.13533,station_longitude=-82.48492,station_name=Crystal\\ Lake\\ Rd,station_time_zone=America/New_York,time_period=Weekly'], ['weatherflow_stats,collector_type=collector_stats,station_elevation=22.802942276000977,station_id=171878,station_latitude=28.13533,station_longitude=-82.48492,station_name=Crystal\\ Lake\\ Rd,station_time_zone=America/New_York,time_period=Yearly']]}]}]}
# SeriesInspect: {'results': [{'statement_id': 0, 'series': [{'columns': ['key'], 'values': [['weatherflow_system_metrics,class=RESTObservationsDeviceHandler,collector_type=collector_rest,device_id=407976,device_name=ST-00173404,device_type=ST,method=process_data,module=handlers.rest_observations_device,serial_number=ST-00173404,station_elevation=22.802942276000977,station_id=171878,station_latitude=28.13533,station_longitude=-82.48492,station_name=Crystal\\ Lake\\ Rd,station_time_zone=America/New_York'], ['weatherflow_system_metrics,class=WebSocketHandler,collector_type=collector_websocket,device_id=407976,device_name=ST-00173404,device_type=ST,method=handle_evt_precip,module=handlers.websocket,serial_number=ST-00173404,source=mqtt,station_elevation=22.802942276000977,station_latitude=28.13533,station_longitude=-82.48492,station_name=Crystal\\ Lake\\ Rd,station_time_zone=America/New_York,type=obs_st'], ['weatherflow_system_metrics,class=WebSocketHandler,collector_type=collector_websocket,device_id=407976,device_name=ST-00173404,device_type=ST,method=handle_evt_strike,module=handlers.websocket,serial_number=ST-00173404,source=mqtt,station_elevation=22.802942276000977,station_latitude=28.13533,station_longitude=-82.48492,station_name=Crystal\\ Lake\\ Rd,station_time_zone=America/New_York,type=obs_st'], ['weatherflow_system_metrics,class=WebSocketHandler,collector_type=collector_websocket,device_id=407976,device_name=ST-00173404,device_type=ST,method=handle_evt_strike,module=handlers.websocket,serial_number=ST-00173404,station_elevation=22.802942276000977,station_latitude=28.13533,station_longitude=-82.48492,station_name=Crystal\\ Lake\\ Rd,station_time_zone=America/New_York'], ['weatherflow_system_metrics,class=WebSocketHandler,collector_type=collector_websocket,device_id=407976,device_name=ST-00173404,device_type=ST,method=handle_obs_st,module=handlers.websocket,serial_number=ST-00173404,source=mqtt,station_elevation=22.802942276000977,station_latitude=28.13533,station_longitude=-82.48492,station_name=Crystal\\ Lake\\ Rd,station_time_zone=America/New_York,type=obs_st'], ['weatherflow_system_metrics,class=WebSocketHandler,collector_type=collector_websocket,device_id=407976,device_name=ST-00173404,device_type=ST,method=handle_rapid_wind,module=handlers.websocket,serial_number=ST-00173404,source=mqtt,station_elevation=22.802942276000977,station_latitude=28.13533,station_longitude=-82.48492,station_name=Crystal\\ Lake\\ Rd,station_time_zone=America/New_York,type=obs_st'], ['weatherflow_system_metrics,class=WebSocketHandler,collector_type=collector_websocket,device_id=407976,device_name=ST-00173404,device_type=ST,method=handle_rapid_wind,module=handlers.websocket,serial_number=ST-00173404,station_elevation=22.802942276000977,station_latitude=28.13533,station_longitude=-82.48492,station_name=Crystal\\ Lake\\ Rd,station_time_zone=America/New_York'], ['weatherflow_system_metrics,class=WebSocketHandler,collector_type=primary,device_id=407976,device_name=ST-00173404,device_type=ST,method=handle_evt_precip,module=handlers.websocket,serial_number=ST-00173404,source=mqtt,station_elevation=22.802942276000977,station_latitude=28.13533,station_longitude=-82.48492,station_name=Crystal\\ Lake\\ Rd,station_time_zone=America/New_York,type=obs_st'], ['weatherflow_system_metrics,class=WebSocketHandler,collector_type=primary,device_id=407976,device_name=ST-00173404,device_type=ST,method=handle_evt_strike,module=handlers.websocket,serial_number=ST-00173404,source=mqtt,station_elevation=22.802942276000977,station_latitude=28.13533,station_longitude=-82.48492,station_name=Crystal\\ Lake\\ Rd,station_time_zone=America/New_York,type=obs_st'], ['weatherflow_system_metrics,class=WebSocketHandler,collector_type=primary,device_id=407976,device_name=ST-00173404,device_type=ST,method=handle_evt_strike,module=handlers.websocket,serial_number=ST-00173404,station_elevation=22.802942276000977,station_latitude=28.13533,station_longitude=-82.48492,station_name=Crystal ...

# %%
def get_series_data(db_name, series_name, start_time, end_time):
    if check_database_exists(db_name):
        query = f'SELECT * FROM "{series_name}" WHERE time >= \'{start_time}\' AND time <= \'{end_time}\''
        data_url = f"{base_url}/query?db={db_name}&q={query}"
        response = requests.get(data_url)
        if response.status_code == 200:
            return response.json()
        else:
            return None
    else:
        return f"Database '{db_name}' does not exist."
    
start_time = "2023-10-01T00:00:00Z"
end_time = "2025-10-02T00:00:00Z"
series_name = "weatherflow_obs"
# print(f"SeriesData: {get_series_data('weatherflow', series_name, start_time, end_time)}")
import pandas as pd
def convert_to_dataframe(series_data):
    if series_data and "results" in series_data and len(series_data["results"]) > 0:
        series = series_data["results"][0]["series"]
        if series:
            columns = series[0]["columns"]
            values = series[0]["values"]
            return pd.DataFrame(values, columns=columns)
    return None
df = convert_to_dataframe(get_series_data('weatherflow', series_name, start_time, end_time))
df
# Out:
#                      time  air_density  air_temperature  battery  \
# 0    2025-07-14T15:59:44Z      1.15090             33.2     2.77
# 1    2025-07-14T15:59:44Z      1.15090             33.2     2.77
# 2    2025-07-14T16:00:44Z      1.15090             33.2     2.76
# 3    2025-07-14T16:00:44Z      1.15090             33.2     2.76
# 4    2025-07-14T16:01:44Z      1.15041             33.3     2.77
# ..                    ...          ...              ...      ...
# 404  2025-07-14T19:56:44Z      1.15214             32.9     2.77
# 405  2025-07-14T19:57:44Z      1.15176             33.0     2.76
# 406  2025-07-14T19:57:44Z      1.15176             33.0     2.76
# 407  2025-07-14T19:58:44Z      1.15127             33.1     2.76
# 408  2025-07-14T19:58:44Z      1.15127             33.1     2.76
#
#      calculated_absolute_humidity  calculated_beaufort_scale_rating  \
# 0                       26.750013                                 1
# 1                       26.750013                                 1
# 2                       26.750013                                 1
# 3                       26.750013                                 1
# 4                       26.891528                                 1
# ..                            ...                               ...
# 404                     26.329280                                 0
# 405                     26.831479                                 0
# 406                     26.831479                                 0
# 407                     26.973644                                 0
# 408                     26.973644                                 0
#
#      calculated_dew_point  calculated_dew_point_buck  calculated_heat_index  \
# 0               27.688359                  27.506113              45.480488
# 1               27.688359                  27.506113              45.480488
# 2               27.688359                  27.506113              45.480488
# 3               27.688359                  27.506113              45.480488
# 4               27.784330                  27.600674              45.826476
# ..                    ...                        ...                    ...
# 404             27.400436                  27.222385              44.458131
# 405             27.729712                  27.546373              45.252950
# 406             27.729712                  27.546373              45.252950
# 407             27.825855                  27.641102              45.600928
# 408             27.825855                  27.641102              45.600928
#
#      calculated_sea_level_pressure  ...    type     uv  \
# 0                      1014.676361  ...  obs_st  10.00
# 1                      1014.676361  ...  obs_st  10.00
# 2                      1014.676361  ...  obs_st  10.36
# 3                      1014.676361  ...  obs_st  10.36
# 4                      1014.575265  ...  obs_st   8.33
# ..                             ...  ...     ...    ...
# 404                    1014.779144  ...  obs_st   8.85
# 405                    1014.778300  ...  obs_st   3.13
# 406                    1014.778300  ...  obs_st   3.13
# 407                    1014.677203  ...  obs_st   4.32
# 408                    1014.677203  ...  obs_st   4.32
#
#      wet_bulb_globe_temperature  wet_bulb_temperature wind_avg  wind_chill  \
# 0                          35.2                  29.1      0.5        33.2
# 1                          35.2                  29.1      0.5        33.2
# 2                          33.5                  29.1      1.1        33.2
# 3                          33.5                  29.1      1.1        33.2
# 4                          33.5                  29.1      0.8        33.3
# ..                          ...                   ...      ...         ...
# 404                        34.6                  28.7      0.4        32.9
# 405                        31.8                  29.0      0.3        33.0
# 406                        31.8                  29.0      0.3        33.0
# 407                        32.6                  29.1      0.2        33.1
# 408                        32.6                  29.1      0.2        33.1
#
#     wind_direction wind_gust wind_lull  wind_sample_interval
# 0              295       1.1       0.0                     3
# 1              295       1.1       0.0                     3
# 2              287       1.6       0.8                     3
# 3              287       1.6       0.8                     3
# 4              291       1.3       0.3                     3
# ..             ...       ...       ...                   ...
# 404            285       1.0       0.0                     3
# 405            221       0.9       0.0                     3
# 406            221       0.9       0.0                     3
# 407            230       0.7       0.0                     3
# 408            230       0.7       0.0                     3
#
# [409 rows x 65 columns]

# %%
def check_for_null_entries(df):
    if df is not None:
        null_entries = df[df.isnull().any(axis=1)]
        if not null_entries.empty:
            return null_entries
        else:
            return "No null entries found."
    else:
        return "DataFrame is empty or invalid."

for s in series:
    print(f"NullEntries {s}: {check_for_null_entries(convert_to_dataframe(get_series_data('weatherflow', s[0], start_time, end_time)))}")
# Out:
# NullEntries ['weatherflow_evt_strike']: No null entries found.
# NullEntries ['weatherflow_obs']:                      time  air_density  air_temperature  battery  \
# 0    2025-07-14T15:59:44Z      1.15090             33.2     2.77
# 1    2025-07-14T15:59:44Z      1.15090             33.2     2.77
# 2    2025-07-14T16:00:44Z      1.15090             33.2     2.76
# 3    2025-07-14T16:00:44Z      1.15090             33.2     2.76
# 4    2025-07-14T16:01:44Z      1.15041             33.3     2.77
# ..                    ...          ...              ...      ...
# 404  2025-07-14T19:56:44Z      1.15214             32.9     2.77
# 405  2025-07-14T19:57:44Z      1.15176             33.0     2.76
# 406  2025-07-14T19:57:44Z      1.15176             33.0     2.76
# 407  2025-07-14T19:58:44Z      1.15127             33.1     2.76
# 408  2025-07-14T19:58:44Z      1.15127             33.1     2.76
#
#      calculated_absolute_humidity  calculated_beaufort_scale_rating  \
# 0                       26.750013                                 1
# 1                       26.750013                                 1
# 2                       26.750013                                 1
# 3                       26.750013                                 1
# 4                       26.891528                                 1
# ..                            ...                               ...
# 404                     26.329280                                 0
# 405                     26.831479                                 0
# 406                     26.831479                                 0
# 407                     26.973644                                 0
# 408                     26.973644                                 0
#
#      calculated_dew_point  calculated_dew_point_buck  calculated_heat_index  \
# 0               27.688359                  27.506113              45.480488
# 1               27.688359                  27.506113              45.480488
# 2               27.688359                  27.506113              45.480488
# 3               27.688359                  27.506113              45.480488
# 4               27.784330                  27.600674              45.826476
# ..                    ...                        ...                    ...
# 404             27.400436                  27.222385              44.458131
# 405             27.729712                  27.546373              45.252950
# 406             27.729712                  27.546373              45.252950
# 407             27.825855                  27.641102              45.600928
# 408             27.825855                  27.641102              45.600928
#
#      calculated_sea_level_pressure  ...    type     uv  \
# 0                      1014.676361  ...  obs_st  10.00
# 1                      1014.676361  ...  obs_st  10.00
# 2                      1014.676361  ...  obs_st  10.36
# 3                      1014.676361  ...  obs_st  10.36
# 4                      1014.575265  ...  obs_st   8.33
# ..                             ...  ...     ...    ...
# 404                    1014.779144  ...  obs_st   8.85
# 405                    1014.778300  ...  obs_st   3.13
# 406                    1014.778300  ...  obs_st   3.13
# 407                    1014.677203  ...  obs_st   4.32
# 408                    1014.677203  ...  obs_st   4.32
#
#      wet_bulb_globe_temperature  wet_bulb_temperature wind_avg  wind_chill  \
# 0                          35.2                  29.1      0.5        33.2
# 1                          35.2                  29.1      0.5        33.2
# 2                          33.5                  29.1      1.1        33.2
# 3                          33.5                  29.1      1.1        33.2
# 4                          33.5                  29.1      0.8        33.3
# ..                          ...                   ...      ...         ...
# 404                        34.6                  28.7      0.4        32.9
# 405                        31.8                  29.0      0.3        33.0
# 406                        31.8                  29.0      0.3        33.0
# 407                        32.6                  29.1      0.2        33.1
# 408                        32.6                  29.1      0.2        33.1
#
#     wind_direction wind_gust wind_lull  wind_sample_interval
# 0              295       1.1       0.0                     3
# 1              295       1.1       0.0                     3
# 2              287       1.6       0.8                     3
# 3              287       1.6       0.8                     3
# 4              291       1.3       0.3                     3
# ..             ...       ...       ...                   ...
# 404            285       1.0       0.0                     3
# 405            221       0.9       0.0                     3
# 406            221       0.9       0.0                     3
# 407            230       0.7       0.0                     3
# 408            230       0.7       0.0                     3
#
# [409 rows x 65 columns]
# NullEntries ['weatherflow_rapid_wind']:                       time       collector_type device_id  device_name  \
# 18    2025-07-14T15:59:20Z  collector_websocket    407976  ST-00173404
# 19    2025-07-14T15:59:20Z              primary    407976  ST-00173404
# 38    2025-07-14T15:59:50Z  collector_websocket    407976  ST-00173404
# 39    2025-07-14T15:59:50Z              primary    407976  ST-00173404
# 58    2025-07-14T16:00:20Z  collector_websocket    407976  ST-00173404
# ...                    ...                  ...       ...          ...
# 7545  2025-07-14T19:11:10Z              primary    407976  ST-00173404
# 7620  2025-07-14T19:12:10Z  collector_websocket    407976  ST-00173404
# 7621  2025-07-14T19:12:10Z              primary    407976  ST-00173404
# 7658  2025-07-14T19:12:40Z  collector_websocket    407976  ST-00173404
# 7659  2025-07-14T19:12:40Z              primary    407976  ST-00173404
#
#      device_type serial_number   station_elevation station_latitude  \
# 18            ST   ST-00173404  22.802942276000977         28.13533
# 19            ST   ST-00173404  22.802942276000977         28.13533
# 38            ST   ST-00173404  22.802942276000977         28.13533
# 39            ST   ST-00173404  22.802942276000977         28.13533
# 58            ST   ST-00173404  22.802942276000977         28.13533
# ...          ...           ...                 ...              ...
# 7545          ST   ST-00173404  22.802942276000977         28.13533
# 7620          ST   ST-00173404  22.802942276000977         28.13533
# 7621          ST   ST-00173404  22.802942276000977         28.13533
# 7658          ST   ST-00173404  22.802942276000977         28.13533
# 7659          ST   ST-00173404  22.802942276000977         28.13533
#
#      station_longitude     station_name station_time_zone  timestamp  \
# 18           -82.48492  Crystal Lake Rd  America/New_York        NaN
# 19           -82.48492  Crystal Lake Rd  America/New_York        NaN
# 38           -82.48492  Crystal Lake Rd  America/New_York        NaN
# 39           -82.48492  Crystal Lake Rd  America/New_York        NaN
# 58           -82.48492  Crystal Lake Rd  America/New_York        NaN
# ...                ...              ...               ...        ...
# 7545         -82.48492  Crystal Lake Rd  America/New_York        NaN
# 7620         -82.48492  Crystal Lake Rd  America/New_York        NaN
# 7621         -82.48492  Crystal Lake Rd  America/New_York        NaN
# 7658         -82.48492  Crystal Lake Rd  America/New_York        NaN
# 7659         -82.48492  Crystal Lake Rd  America/New_York        NaN
#
#       wind_speed
# 18          0.81
# 19          0.81
# 38          1.15
# 39          1.15
# 58          0.93
# ...          ...
# 7545        0.00
# 7620        0.00
# 7621        0.00
# 7658        0.00
# 7659        0.00
#
# [714 rows x 13 columns]
# NullEntries ['weatherflow_stats']:                      time  battery   collector_type  humidity  humidity_high  \
# 0    2025-02-01T00:00:00Z      2.7  collector_stats      53.0           60.0
# 1    2025-02-24T00:00:00Z      2.7  collector_stats      52.0           60.0
# 2    2025-02-28T23:59:59Z      2.7  collector_stats      53.0           60.0
# 3    2025-03-01T00:00:00Z      2.7  collector_stats      51.0           54.0
# 4    2025-03-01T23:59:59Z      2.7  collector_stats      51.0           54.0
# ..                    ...      ...              ...       ...            ...
# 143  2025-06-28T23:59:59Z      NaN  collector_stats       NaN            NaN
# 144  2025-06-29T23:59:59Z      NaN  collector_stats       NaN            NaN
# 146  2025-06-30T23:59:59Z      NaN  collector_stats       NaN            NaN
# 148  2025-07-01T23:59:59Z      NaN  collector_stats       NaN            NaN
# 149  2025-07-02T23:59:59Z      2.7  collector_stats      85.0           95.0
#
#      humidity_low  local_precipitation_accumulation_final  \
# 0            27.0                                     NaN
# 1            27.0                                     NaN
# 2            27.0                                     NaN
# 3            44.0                                     NaN
# 4            44.0                                     NaN
# ..            ...                                     ...
# 143           NaN                                     NaN
# 144           NaN                                     NaN
# 146           NaN                                     NaN
# 148           NaN                                     NaN
# 149          65.0                                     NaN
#
#      local_precipitation_accumulation_today  \
# 0                                  0.866062
# 1                                  0.866062
# 2                                  0.866062
# 3                                  0.000000
# 4                                  0.000000
# ..                                      ...
# 143                                0.000000
# 144                                0.000000
# 146                                0.000000
# 148                                0.000000
# 149                               20.160300
#
#      local_precipitation_minutes_final  local_precipitation_minutes_today  \
# 0                                  NaN                                  3
# 1                                  NaN                                  3
# 2                                  NaN                                  3
# 3                                  NaN                                  0
# 4                                  NaN                                  0
# ..                                 ...                                ...
# 143                                NaN                                  0
# 144                                NaN                                  0
# 146                                NaN                                  0
# 148                                NaN                                  0
# 149                                NaN                                101
#
#      ...  temperature_low  time_period   uv  uv_high  uv_low  wind_average  \
# 0    ...             20.1      Monthly  0.1     3.23     0.0           0.0
# 1    ...             20.1       Weekly  0.0     3.23     0.0           0.0
# 2    ...             20.1        Daily  0.1     3.23     0.0           0.0
# 3    ...             20.1      Monthly  0.0     0.02     0.0           0.0
# 4    ...             20.1        Daily  0.0     0.02     0.0           0.0
# ..   ...              ...          ...  ...      ...     ...           ...
# 143  ...              NaN        Daily  NaN      NaN     NaN           NaN
# 144  ...              NaN        Daily  NaN      NaN     NaN           NaN
# 146  ...              NaN        Daily  NaN      NaN     NaN           NaN
# 148  ...              NaN        Daily  NaN      NaN     NaN           NaN
# 149  ...             24.4        Daily  2.7    14.19     0.0           0.2
#
#      wind_direction  wind_gust  wind_interval  wind_lull
# 0              38.0       1.69           15.0        0.0
# 1              22.0       1.69           15.0        0.0
# 2              38.0       1.69           15.0        0.0
# 3               7.0       0.39           15.0        0.0
# 4               7.0       0.39           15.0        0.0
# ..              ...        ...            ...        ...
# 143             NaN        NaN            NaN        NaN
# 144             NaN        NaN            NaN        NaN
# 146             NaN        NaN            NaN        NaN
# 148             NaN        NaN            NaN        NaN
# 149           249.0       4.01            3.0        0.0
#
# [148 rows x 42 columns]
# NullEntries ['weatherflow_system_metrics']:                        time  active_tasks    bytes  \
# 0      2025-07-14T15:58:55Z           NaN      NaN
# 1      2025-07-14T15:58:55Z           NaN    522.0
# 2      2025-07-14T15:58:55Z           NaN  33600.0
# 3      2025-07-14T15:58:55Z           NaN      NaN
# 4      2025-07-14T15:58:55Z           NaN      NaN
# ...                     ...           ...      ...
# 33207  2025-07-14T19:58:50Z           1.0      NaN
# 33208  2025-07-14T19:58:50Z           NaN    125.0
# 33209  2025-07-14T19:58:50Z           NaN      NaN
# 33210  2025-07-14T19:58:50Z           NaN      NaN
# 33211  2025-07-14T19:58:50Z           NaN      NaN
#
#                                class  client_count       collector_type  \
# 0      RESTObservationsDeviceHandler           NaN       collector_rest
# 1                               None           NaN                 None
# 2                               None           NaN                 None
# 3                               None           NaN                 None
# 4                               None           NaN                 None
# ...                              ...           ...                  ...
# 33207                           None           NaN                 None
# 33208                           None           NaN                 None
# 33209               WebSocketHandler           NaN              primary
# 33210                           None           NaN                 None
# 33211               WebSocketHandler           NaN  collector_websocket
#
#       device_id  device_name device_type  duration  ...  serial_number source  \
# 0        407976  ST-00173404          ST       NaN  ...    ST-00173404   None
# 1          None         None        None  0.329024  ...           None   None
# 2          None         None        None  0.348230  ...           None   None
# 3          None         None        None  0.393322  ...           None   None
# 4          None         None        None  0.353504  ...           None   None
# ...         ...          ...         ...       ...  ...            ...    ...
# 33207      None         None        None  0.000061  ...           None   None
# 33208      None         None        None  0.016366  ...           None   None
# 33209    407976  ST-00173404          ST       NaN  ...    ST-00173404   mqtt
# 33210      None         None        None  0.013028  ...           None   None
# 33211    407976  ST-00173404          ST       NaN  ...    ST-00173404   mqtt
#
#         station_elevation station_id station_latitude  station_longitude  \
# 0      22.802942276000977     171878         28.13533          -82.48492
# 1                    None       None             None               None
# 2                    None       None             None               None
# 3                    None       None             None               None
# 4                    None       None             None               None
# ...                   ...        ...              ...                ...
# 33207                None       None             None               None
# 33208                None       None             None               None
# 33209  22.802942276000977       None         28.13533          -82.48492
# 33210                None       None             None               None
# 33211  22.802942276000977       None         28.13533          -82.48492
#
#           station_name station_time_zone timestamp_delta    type
# 0      Crystal Lake Rd  America/New_York       11.857615    None
# 1                 None              None             NaN    None
# 2                 None              None             NaN    None
# 3                 None              None             NaN    None
# 4                 None              None             NaN    None
# ...                ...               ...             ...     ...
# 33207             None              None             NaN    None
# 33208             None              None             NaN    None
# 33209  Crystal Lake Rd  America/New_York        0.967455  obs_st
# 33210             None              None             NaN    None
# 33211  Crystal Lake Rd  America/New_York        0.967455  obs_st
#
# [33212 rows x 26 columns]

# %%
def delete_missing_series_entries(db_name, series_name):
    if check_database_exists(db_name):
        query = f'DELETE FROM "{series_name}" WHERE collector_type = \'collector_rest\''
        delete_url = f"{base_url}/query?db={db_name}&q={query}"
        response = requests.post(delete_url)
        if response.status_code == 204:
            return f"Entries in series '{series_name}' deleted successfully."
        else:
            return f"Failed to delete entries: {response.text}"
    else:
        return f"Database '{db_name}' does not exist."
    
delete_missing_series_entries('weatherflow', 'weatherflow_obs')
# Out:
# 'Failed to delete entries: {"results":[{"statement_id":0}]}\n'

# %%
def test_query(db_name):
    query_url = f'query?db={db_name}&epoch=ms&q=SELECT+mean%28%22wind_speed%22%29+%2A+2.236936+FROM+%22weatherflow_rapid_wind%22+WHERE+%28%22station_name%22+%3D~+%2F%5ECrystal+Lake+Rd%24%2F+AND+%22collector_type%22+%3D~+%2F%5Elocal-udp%24%2F%29+AND+time+%3E%3D+1752687414409ms+and+time+%3C%3D+1752687474409ms+GROUP+BY+time%285s%29+fill%28null%29+ORDER+BY+time+ASC HTTP/1.1" 200 57 "-" "Grafana/12.0.2" 9aabfb6a-626b-11f0-b2ce-e6c251d00ca3 804 2025-07-16 13:37:54{"lvl":"info","ts":"2025-07-16T17:37:54.450246Z","msg":"Executing query","log_id":"0xly7Iy0000","service":"query","query":"SELECT mean(precip_accumulated) * 0.039 FROM weatherflow.autogen.weatherflow_obs WHERE (station_name =~ /^Crystal Lake Rd$/ AND collector_type =~ /^local-udp$/) AND time >= 486844h AND time <= 1752687474408ms GROUP BY time(1m) ORDER BY time ASC"}'
    response = requests.get(f'{base_url}/{query_url}')
    print(response.json())

test_query('weatherflow')
# Out:
# {'error': 'error parsing query: found primary, expected regex at line 1, char 92'}
